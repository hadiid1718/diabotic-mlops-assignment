# %% [markdown]
# # EDA — Part 2: Visualizations
#
# This notebook presents the exploratory data analysis (Part 2) visuals created for the diabetes dataset. Each figure was generated by `scripts/eda.py` and saved in the `figures/` folder. Below we display the images with short commentary.

# %%
from IPython.display import Image, display
import os
FOLDER = os.path.join('..', 'figures')
files = {f: os.path.exists(os.path.join(FOLDER, f)) for f in [
    'gender_distribution.png',
    'age_histogram.png',
    'bmi_histogram.png',
    'bmi_vs_hba1c_scatter.png',
    'age_vs_hba1c_scatter.png',
    'bmi_boxplot_diabetic_vs_non.png'
]}
print('Figures folder:', os.path.abspath(FOLDER))
print('Files exist:')
for k,v in files.items():
    print(f' - {k}:', 'FOUND' if v else 'MISSING')

# %% [markdown]
# ## 1) Male vs Female Distribution

# %%
display(Image(filename=os.path.join('..', 'figures', 'gender_distribution.png')))

# %% [markdown]
# **Commentary:** Shows the counts of female and male patients (note many missing `Gender` values in the extracted data).

# %% [markdown]
# ## 2) Age Distribution

# %%
display(Image(filename=os.path.join('..', 'figures', 'age_histogram.png')))

# %% [markdown]
# ## 3) BMI Distribution

# %%
display(Image(filename=os.path.join('..', 'figures', 'bmi_histogram.png')))

# %% [markdown]
# ## 4) BMI vs HbA1c (by class)

# %%
display(Image(filename=os.path.join('..', 'figures', 'bmi_vs_hba1c_scatter.png')))
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %% [markdown]
# ## 5) Age vs HbA1c (by class)

# %%
display(Image(filename=os.path.join('..', 'figures', 'age_vs_hba1c_scatter.png')))

# %% [markdown]
# ## 6) BMI boxplot: Diabetic vs Non-Diabetic

# %%
display(Image(filename=os.path.join('..', 'figures', 'bmi_boxplot_diabetic_vs_non.png')))
